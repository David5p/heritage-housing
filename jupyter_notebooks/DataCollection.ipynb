# %% [markdown]
# # **Data Collection Notebook**

# %% [markdown]
# ## Objectives
#
# * Fetch data from Kaggle and save it as raw data.
# * Inspect the data and save it under outputs/datasets/collection
#
# ## Inputs
#
# * Kaggle JSON file - the authentication token.
#
# ## Outputs
#
# * Generate Dataset: outputs/datasets/collection/HousingPricesData.csv
#
# ## Additional Comments
#
# * In the work environment, projects are not done using Kaggle data, but instead, the data comes from multiple data sources that may be hosted internally (like in a data warehouse) or outside your company. For this project learning context, we are fetching the data from Kaggle.
#
# * Another aspect is that in the work environment, the data has never been pushed to a public repository due to security reasons. Just for this project learning context, we are hosting the data in a public repository.

# %% [markdown]
# ---

# %% [markdown]
# ## Install Python packages in the notebooks ##
#
# ### Change working directory ###

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\david\\Portfolio 5\\heritage-housing\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print(f"Current directory changed to: {os.getcwd()}")
# Out:
# Current directory changed to: c:\Users\david\Portfolio 5\heritage-housing

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\david\\Portfolio 5\\heritage-housing'

# %% [markdown]
# # Fetch data from Kaggle

# %% [markdown]
# Install Kaggle package to fetch the data

# %%
# %pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.8.3-py3-none-any.whl.metadata (16 kB)
# Collecting black>=24.10.0 (from kaggle)
#   Downloading black-25.12.0-cp312-cp312-win_amd64.whl.metadata (86 kB)
# Requirement already satisfied: bleach in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from kaggle) (6.3.0)
# Collecting kagglesdk<1.0,>=0.1.14 (from kaggle)
#   Downloading kagglesdk-0.1.14-py3-none-any.whl.metadata (13 kB)
# Collecting mypy>=1.15.0 (from kaggle)
#   Downloading mypy-1.19.1-cp312-cp312-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: packaging in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from kaggle) (25.0)
# Collecting protobuf (from kaggle)
#   Downloading protobuf-6.33.3-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: python-dateutil in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from kaggle) (2.9.0.post0)
# Collecting python-slugify (from kaggle)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: six>=1.10 in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from kaggle) (1.17.0)
# Collecting tqdm (from kaggle)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting types-requests (from kaggle)
#   Downloading types_requests-2.32.4.20260107-py3-none-any.whl.metadata (2.0 kB)
# Collecting types-tqdm (from kaggle)
#   Downloading types_tqdm-4.67.0.20250809-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from kaggle) (2.6.3)
# Collecting click>=8.0.0 (from black>=24.10.0->kaggle)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting mypy-extensions>=0.4.3 (from black>=24.10.0->kaggle)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=0.9.0 (from black>=24.10.0->kaggle)
#   Downloading pathspec-1.0.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs>=2 in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from black>=24.10.0->kaggle) (4.5.1)
# Collecting pytokens>=0.3.0 (from black>=24.10.0->kaggle)
#   Downloading pytokens-0.3.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing_extensions>=4.6.0 in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from mypy>=1.15.0->kaggle) (4.15.0)
# Collecting librt>=0.6.2 (from mypy>=1.15.0->kaggle)
#   Downloading librt-0.7.7-cp312-cp312-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: webencodings in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from bleach->kaggle) (0.5.1)
# Collecting text-unidecode>=1.3 (from python-slugify->kaggle)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from requests->kaggle) (2026.1.4)
# Requirement already satisfied: colorama in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Downloading kaggle-1.8.3-py3-none-any.whl (102 kB)
# Downloading black-25.12.0-cp312-cp312-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 18.8 MB/s eta 0:00:00
# Downloading kagglesdk-0.1.14-py3-none-any.whl (159 kB)
# Downloading mypy-1.19.1-cp312-cp312-win_amd64.whl (10.1 MB)
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    -------------------------- ------------- 6.8/10.1 MB 35.0 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.1 MB 29.6 MB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 23.4 MB/s eta 0:00:00
# Downloading protobuf-6.33.3-cp310-abi3-win_amd64.whl (436 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading types_requests-2.32.4.20260107-py3-none-any.whl (20 kB)
# Downloading types_tqdm-4.67.0.20250809-py3-none-any.whl (24 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Downloading librt-0.7.7-cp312-cp312-win_amd64.whl (49 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pathspec-1.0.3-py3-none-any.whl (55 kB)
# Downloading pytokens-0.3.0-py3-none-any.whl (12 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Installing collected packages: text-unidecode, types-requests, tqdm, pytokens, python-slugify, protobuf, pathspec, mypy-extensions, librt, click, types-tqdm, mypy, kagglesdk, black, kaggle
# Successfully installed black-25.12.0 click-8.3.1 kaggle-1.8.3 kagglesdk-0.1.14 librt-0.7.7 mypy-1.19.1 mypy-extensions-1.1.0 pathspec-1.0.3 protobuf-6.33.3 python-slugify-8.0.4 pytokens-0.3.0 text-unidecode-1.3 tqdm-4.67.1 types-requests-2.32.4.20260107 types-tqdm-4.67.0.20250809
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()

KaggleDatasetPath = "codeinstitute/housing-prices-data"
DestinationFolder = "inputs/datasets/raw"
os.makedirs(DestinationFolder, exist_ok=True)

! kaggle datasets download -d {KaggleDatasetPath} -p {DestinationFolder}

! powershell -Command "Expand-Archive -Path '{DestinationFolder}\\*.zip' -DestinationPath '{DestinationFolder}'; Remove-Item '{DestinationFolder}\\*.zip'; Remove-Item 'kaggle.json'"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/codeinstitute/housing-prices-data
# License(s): unknown
# housing-prices-data.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# ---

# %% [markdown]
# # Load and Inspect Kaggle data

# %% [markdown]
# Section 2 content

# %%
# !pip install pandas
import pandas as pd

df = pd.read_csv(r"inputs/datasets/raw/house-price-20211124T154130Z-001/house-price/house_prices_records.csv")
df.head()
# Out:
# Requirement already satisfied: pandas in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from pandas) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\david\portfolio 5\heritage-housing\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#    1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0       856     854.0           3.0           No         706          GLQ
# 1      1262       0.0           3.0           Gd         978          ALQ
# 2       920     866.0           3.0           Mn         486          GLQ
# 3       961       NaN           NaN           No         216          ALQ
# 4      1145       NaN           4.0           Av         655          GLQ
#
#    BsmtUnfSF  EnclosedPorch  GarageArea GarageFinish  ...  LotFrontage  \
# 0        150            0.0         548          RFn  ...         65.0
# 1        284            NaN         460          RFn  ...         80.0
# 2        434            0.0         608          RFn  ...         68.0
# 3        540            NaN         642          Unf  ...         60.0
# 4        490            0.0         836          RFn  ...         84.0
#
#    MasVnrArea OpenPorchSF  OverallCond  OverallQual  TotalBsmtSF  WoodDeckSF  \
# 0       196.0          61            5            7          856         0.0
# 1         0.0           0            8            6         1262         NaN
# 2       162.0          42            5            7          920         NaN
# 3         0.0          35            5            7          756         NaN
# 4       350.0          84            5            8         1145         NaN
#
#    YearBuilt  YearRemodAdd  SalePrice
# 0       2003          2003     208500
# 1       1976          1976     181500
# 2       2001          2002     223500
# 3       1915          1970     140000
# 4       2000          2000     250000
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   1stFlrSF       1460 non-null   int64
#  1   2ndFlrSF       1374 non-null   float64
#  2   BedroomAbvGr   1361 non-null   float64
#  3   BsmtExposure   1422 non-null   object
#  4   BsmtFinSF1     1460 non-null   int64
#  5   BsmtFinType1   1315 non-null   object
#  6   BsmtUnfSF      1460 non-null   int64
#  7   EnclosedPorch  136 non-null    float64
#  8   GarageArea     1460 non-null   int64
#  9   GarageFinish   1225 non-null   object
#  10  GarageYrBlt    1379 non-null   float64
#  11  GrLivArea      1460 non-null   int64
#  12  KitchenQual    1460 non-null   object
#  13  LotArea        1460 non-null   int64
#  14  LotFrontage    1201 non-null   float64
#  15  MasVnrArea     1452 non-null   float64
#  16  OpenPorchSF    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  OverallQual    1460 non-null   int64
#  19  TotalBsmtSF    1460 non-null   int64
#  20  WoodDeckSF     155 non-null    float64
#  21  YearBuilt      1460 non-null   int64
#  22  YearRemodAdd   1460 non-null   int64
#  23  SalePrice      1460 non-null   int64
# dtypes: float64(7), int64(13), object(4)
# memory usage: 273.9+ KB

# %% [markdown]
# We want to check if any houses appear multiple times.

# %%
duplicates = df[df.duplicated()]
print(f"Number of duplicate rows: {len(duplicates)}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %%
import os
os.makedirs('outputs/datasets/collection', exist_ok=True)

df.to_csv('outputs/datasets/collection/house_prices_records.csv', index=False)
